# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('Productivity.csv')
df
af = df.plot(kind = 'bar', color = 'b', alpha = 0.6)
af.set_xlabel('Time of Day')
af.set_ylabel('Productivity Level')
# Out:
# Text(0, 0.5, 'Productivity Level')
